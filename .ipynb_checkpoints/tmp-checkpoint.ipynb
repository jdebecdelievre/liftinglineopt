# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 100
t = np.linspace(-1,1,N)
f = np.cos(t)
plt.plot(t,f)

# %%
S = np.sin(np.arange(1, N+1)[None, :] @ np.arccos(t)[:, None])

# %%
S
# Out:
# array([[0.79081641]])

# %%
np.arange(1, N+1)[None, :] .shape
# Out:
# (1, 100)
